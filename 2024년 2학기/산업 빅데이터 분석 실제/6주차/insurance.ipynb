# %%
import pandas as pd

insurance_df = pd.read_csv("/Users/jipyeongseon/Desktop/대학원/산업 빅데이터 분석 실제/insurance.csv")

print(insurance_df)
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# 5      31  female  25.7         0     no  southeast   3756.62
# 6      46  female  33.4         1     no  southeast   8240.59
# 7      37  female  27.7         3     no  northwest   7281.51
# 8      37    male  29.8         2     no  northeast   6406.41
# 9      60  female  25.8         0     no  northwest  28923.14
# 10     25    male  26.2         0     no  northeast   2721.32
# 11     62  female  26.3         0    yes  southeast  27808.73
# 12     23    male  34.4         0     no  southwest   1826.84
# 13     56  female  39.8         0     no  southeast  11090.72
# ...

# %%
#1. 불필요한 열 제거하기
# Number 열
import pandas as pd

insurance_df = pd.read_csv("/Users/jipyeongseon/Desktop/대학원/산업 빅데이터 분석 실제/insurance.csv")

insurance_df.drop(columns='Number', inplace=True)

#2. 중복 데이터 찾기 및 제거하기
#duplicated() & drop_duplicate()
insurance_df[insurance_df.duplicated()]

insurance_df.drop_duplicates(inplace=True)
insurance_df[insurance_df.duplicated()]
insurance_df.tail(10)

#3. Null 값 제거
#dropna()
insurance_df.dropna(inplace=True)
insurance_df.isnull().sum()

#4.rename() 이용하여 열 이름 바꾸기
#Gender -> gender, Insurance Fee -> charges
insurance_df.rename(columns={
    'Gender': 'gender',
    'Insurance Fee' : 'charges'
}, inplace=True)
insurance_df.columns

#5.replace() 이용하여 행 값 바꾸기
#female -> 1, male ->0
insurance_df.replace({'gender' : {'male' : 0}}, inplace=True)
insurance_df.replace({'gender' : {'female' : 1}}, inplace=True)

#6. 이상 값 처리
import seaborn as sns

insurance_df.drop(insurance_df[titanic_df.Fare >= 500].index,
inplace = True)
sns.boxplot(y = insurance_df['Fare'] );

#7. Min-max 방법을 이용하여 데이터 정규화

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
insurance_df[[‘Fare’]] = scaler.fit_transform(insurance_df[[‘Fare']])
insurance_df.describe()

#8. 'charges' 컬럼과 상관 관계가없는 컬럼 삭제
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-6d4ae622a7a9> in <module>()
#       6
#       7
# ----> 8 insurance_df.drop(columns='Number', inplace=True)
#       9
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
